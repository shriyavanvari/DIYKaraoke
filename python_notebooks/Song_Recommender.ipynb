# %%
pip install sklearn-recommender
# Out:
# Requirement already satisfied: sklearn-recommender in /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages (0.1.5)
# Requirement already satisfied: numpy in /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages (from sklearn-recommender) (1.18.1)
# Requirement already satisfied: scipy in /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages (from sklearn-recommender) (1.4.1)
# Requirement already satisfied: nltk in /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages (from sklearn-recommender) (3.4.5)
# Requirement already satisfied: pandas in /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages (from sklearn-recommender) (1.0.1)
# Requirement already satisfied: scikit-learn in /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages (from sklearn-recommender) (0.22.1)
# Requirement already satisfied: six in /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages (from nltk->sklearn-recommender) (1.14.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages (from pandas->sklearn-recommender) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages (from pandas->sklearn-recommender) (2019.3)
# Requirement already satisfied: joblib>=0.11 in /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn-recommender) (0.14.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

import pandas
from sklearn.model_selection import train_test_split

import numpy as np
import time
from sklearn.externals import joblib
# Out:
# /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
triplets_file = '10000.txt'
songs_metadata_file = 'song_data.csv'

# %%
#importing all the required libraries
import numpy as np
import pandas as pd
#importing both the datasets
songmetadata = pd.read_csv(r'song_data.csv')
#one of the file is a text file hence we import it with pd.read_fwf
#fwf stands for fixed width file
othersongdata = pd.read_fwf(r'10000.txt')

# %%
#naming the columns for the othersongdata
othersongdata.columns = ['user_id','song_id','listen_count']

# %%
#merging both the datasets and removing duplicates
song_df = pd.merge(othersongdata, songmetadata.drop_duplicates(['song_id']), on="song_id", how="left")
#writing the file in .csv to visualize in Tableau
song_df.to_csv(r'Processed_Data.csv', index = False)

# %%
song_df
# Out:
#                                           user_id             song_id  \
# 0        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B
# 1        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0
# 2        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D
# 3        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273
# 4        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODDNQT12A6D4F5F7E
# ...                                           ...                 ...
# 1999994  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJEYPO12AAA8C6B0E
# 1999995  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJJYDE12AF729FC16
# 1999996  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJKQSF12A6D4F5EE9
# 1999997  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJUXGA12AC961885C
# 1999998  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJYOLS12A8C13C06F
#
#          listen_count                           title  \
# 0                   2                 Entre Dos Aguas
# 1                   1                        Stronger
# 2                   1                  Constellations
# 3                   1                    Learn To Fly
# 4                   5    Apuesta Por El Rock 'N' Roll
# ...               ...                             ...
# 1999994             2       Ignorance (Album Version)
# 1999995             4          Two Is Better Than One
# 1999996             3  What I've Done (Album Version)
# 1999997             1                              Up
# 1999998             1      Soil_ Soil (Album Version)
#
#                                release  \
# 0                  Flamenco Para Niños
# 1                           Graduation
# 2                    In Between Dreams
# 3        There Is Nothing Left To Lose
# 4                Antología Audiovisual
# ...                                ...
# 1999994                      Ignorance
# 1999995                     Love Drunk
# 1999996                 What I've Done
# 1999997                      My Worlds
# 1999998                        The Con
#
#                                     artist_name  year
# 0                                 Paco De Lucia  1976
# 1                                    Kanye West  2007
# 2                                  Jack Johnson  2005
# 3                                  Foo Fighters  1999
# 4                           Héroes del Silencio  2007
# ...                                         ...   ...
# 1999994                                Paramore     0
# 1999995  Boys Like Girls featuring Taylor Swift  2009
# 1999996                             Linkin Park  2007
# 1999997                           Justin Bieber  2010
# 1999998                          Tegan And Sara  2007
#
# [1999999 rows x 7 columns]

# %% [markdown]
# # Step 1: Data preprocessing completed

# %% [markdown]
# # Step 2: Recommender System 1 - Popular Playlist

# %%
import pandas as pd
songmetadata = pd.read_csv(r'song_data.csv')
othersongdata = pd.read_fwf(r'10000.txt')
songmetadata = pd.DataFrame(songmetadata)
othersongdata.columns = ['user_id','song_id','listen_count']
song_df = pd.merge(othersongdata, songmetadata.drop_duplicates(['song_id']), on="song_id", how ="left")
song_grouped = song_df.groupby(['title']).agg({"listen_count":"count"})
grouped_sum = song_grouped['listen_count'].sum()

#calculating the percent share of each song in listen count
song_grouped['percentage'] = song_grouped['listen_count'].div(grouped_sum)*100

#sorting the dataset with respect to listen count
song_grouped = song_grouped.sort_values(['listen_count'],ascending = True)
song_df = song_df['listen_count'].astype(float)
popular = song_grouped.sort_values(by = 'listen_count')

#filtering the top ten songs in the dataset
# popularsongs = popular[9517:9567]
popularsongs = popular
popularsongs = pd.DataFrame(popularsongs.reset_index())
recommendedSongs = popularsongs.sort_values('listen_count', ascending = False)
# popularsongs

# %%
recommendedSongs
# Out:
#                                title  listen_count  percentage
# 9566                   Sehr kosmisch          8277     0.41385
# 9565                            Undo          7032     0.35160
# 9564  Dog Days Are Over (Radio Edit)          6949     0.34745
# 9563                  You're The One          6729     0.33645
# 9562                         Revelry          6145     0.30725
# ...                              ...           ...         ...
# 4                             Scared            51     0.00255
# 3               Historia Del Portero            51     0.00255
# 2                 Don´t Leave Me Now            50     0.00250
# 1                No Creo En El Jamas            48     0.00240
# 0         Ghosts (Toxic Avenger Mix)            48     0.00240
#
# [9567 rows x 3 columns]

# %% [markdown]
# # Step 3: Recommender System 2 - Item based Similarities

# %%
givenSongID_From_FrontEnd = 'SOFVZRE12A8C139783'

# %%
import numpy as np
import pandas as pd
# songmetadata = pd.read_csv(r'E:\Analytics\song_data.csv')
# othersongdata = pd.read_fwf(r'E:\Analytics\10000.txt')
othersongdata.columns = ['user_id','song_id','listen_count']
song_df = pd.merge(othersongdata, songmetadata.drop_duplicates(['song_id']), on="song_id", how="left")
song_grouped = pd.DataFrame(song_df.groupby('song_id')['listen_count'].count())
song_grouped = pd.DataFrame(song_df.groupby('song_id')['listen_count'].count())
song_df.astype({'listen_count': 'int32'},{'song_id':'str'}).dtypes
song_df[song_df['song_id'] == givenSongID_From_FrontEnd]
songs_crosstab = pd.pivot_table(song_df, values = 'listen_count', index = 'user_id', columns = 'song_id')
songs_crosstab.head()
predictor_song_ratings = songs_crosstab[givenSongID_From_FrontEnd]
predictor_song_ratings[predictor_song_ratings>= 1]
similar_songs = songs_crosstab.corrwith(predictor_song_ratings)
corr_listened_song = pd.DataFrame(similar_songs, columns = ['pearsonR'])
corr_listened_song.dropna(inplace = True)
predictor_corr_summary =corr_listened_song.join(song_grouped['listen_count'])
predictor_corr_summary = predictor_corr_summary.sort_values('pearsonR', ascending = False)
final_recommended_songs = predictor_corr_summary[predictor_corr_summary.pearsonR < 0.9999]
final_recommended_songs.sort_values('pearsonR', ascending = False)
final_recommended_songs = final_recommended_songs.reset_index()
song_df_one = song_df.drop(['listen_count'], axis=1)
similar_songs = pd.merge(final_recommended_songs, song_df_one.drop_duplicates(["song_id"]), on="song_id", how="left")
similar_songs = similar_songs.sort_values('pearsonR', ascending = False)
similar_songs.head(50)
# Out:
# /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#                song_id  pearsonR  listen_count  \
# 0   SOECOOL12AB0181A2F  0.999587            75
# 1   SOVMGAJ12AB0181580  0.999539           114
# 2   SOHQFVC12A58A7B234  0.999260            86
# 3   SOVBBUR12AB0181734  0.999097           162
# 4   SOALPQQ12A6701F302  0.999055           200
# 5   SOGFIHA12A8C13951F  0.998997            62
# 6   SOQWVBM12AB0182B5F  0.998938           135
# 7   SOHYHMJ12A6D4F615E  0.998727           217
# 8   SOOYOJU12A670201D3  0.998716           213
# 9   SOOXREU12A8C132CEA  0.998270           134
# 10  SOMMYNX12A58A7D9A6  0.998241           166
# 11  SOJEOBI12A67020189  0.998221           166
# 12  SODWANZ12A8C134AF5  0.998221           105
# 13  SOJVEVP12A8C1419A9  0.997844           102
# 14  SONKAUE12A8C143EF2  0.997805           227
# 15  SOLXSHU12A6D4F98DF  0.997629           182
# 16  SOIZRAA12A6D4F5DA0  0.997380           159
# 17  SOGLOXC12A8C143C29  0.997272            76
# 18  SOQJAJS12A8C139901  0.997176            73
# 19  SOXPSGF12AB0187589  0.997050           269
# 20  SOSUTZH12A81C22A34  0.996751           141
# 21  SOSDTGC12AF72A2BC3  0.996751           275
# 22  SOLRIGA12A8C1413F8  0.996751           126
# 23  SOHALKJ12AB017FCC2  0.996622           605
# 24  SOWZAHB12AF72A4B46  0.996616           164
# 25  SOVKOKD12A6D4F6449  0.996616           112
# 26  SOHRSYD12A58A782E9  0.996616           131
# 27  SOZNAJF12A8C13EDD0  0.996558           189
# 28  SORGRVL12A6310F105  0.996502           332
# 29  SOBADLL12A6D4F8FEA  0.996274           171
# 30  SOILLEE12A58A7D291  0.996116            77
# 31  SOEJNFC12A6D4F979C  0.995871           240
# 32  SOYBAYY12A8151BA7C  0.995871           176
# 33  SOBYPQZ12AB0186DE9  0.995871           121
# 34  SOPFCLB12AB0186DEF  0.995871            93
# 35  SOOQILK12A8C13135E  0.995863            95
# 36  SODKHZY12AF72A6B8F  0.994888           189
# 1     SOVMGAJ12AB0181580  0.999539           114
# 2     SOHQFVC12A58A7B234  0.999260            86
# 3     SOVBBUR12AB0181734  0.999097           162
# 4     SOALPQQ12A6701F302  0.999055           200
# ...                  ...       ...           ...
# 3809  SOWBSGQ12A8C143163 -1.000000           197
# 3810  SOSRERB12A8C139735 -1.000000           361
# 3811  SOYPOQC12A6701F459 -1.000000            88
# 3812  SOMRZNS12AF72AADC5 -1.000000           109
# 3904  SOFJJQC127E94376A2 -1.000000           129
#
#                                        user_id  \
# 0     dd67a78d5f9d8140a0d83849441ca1807f7ea790
# 1     1b704d4cddabea8258bd93497fcb73eab32fa592
# 2     9b887e10a4711486085c4fae2d2599fc0d2c484d
# 3     732f88be38fae217f8ab7e24c20dd072436e3e40
# 4     5d5e0142e54c3bb7b69f548c2ee55066c90700eb
# ...                                        ...
# 3809  cc9fc2eccf0d6fe78d1fb2b0c3ff924f54482169
# 3810  e376b24d90c39bdc1eb4b184b0e1374f2c112801
# 3811  043d81932e75d5749ed5758d6420506e7bc457a5
# 3812  3187e658fd71be99d68d96f3a61a436c8a607365
# 3904  c24ec42f0e449ff39a95a01f0795f833b898f71b
#
#                                                   title  \
# 0                                                 Fever
# 1     Stop This Song (Love Sick Melody) (Bonus Version)
# 2                                Rock Wit U (Awww Baby)
# 3                There will be a happy meeting in Glory
# 4          Put Your Head On My Shoulder (Album Version)
# ...                                                 ...
# 3809                                 Hits From The Bong
# 3810                                            Lullaby
# 3811  Why Do You Love Me (Clean version) (Re-mastere...
# 3812                                         No Regrets
# 3904                                        The Reeling
#
#                                                 release  \
# 0               For Your Entertainment (Deluxe Version)
# 1                                                 Riot!
# 2            Def Jam 25_ Vol. 19 - For The Lover In You
# 3     Joseph Spence: The Complete Folkways Recording...
# 4                                         Michael Bublé
# ...                                                 ...
# 3809                                     The Collection
# 3810  Sing-A-Longs & Lullabies For The Film Curious ...
# 3811                                   Absolute Garbage
# 3812                            I've Been Expecting You
# 3904                                        The Reeling
#
#                     artist_name  year
# 0                  Adam Lambert  2009
# 1                      Paramore     0
# 2                       Ashanti  2003
# 3                 Joseph Spence     0
# 4                 Michael Bublé  2003
# ...                         ...   ...
# 3809               Cypress Hill  1993
# 3810  Jack Johnson / Matt Costa     0
# 3811                    Garbage  2007
# 3812            Robbie Williams  1998
# 3904                Passion Pit  2009
#
# [3905 rows x 8 columns]

# %% [markdown]
# # Step 4: Recommender System 3 - User Based Recommender System

# %% [markdown]
# # Step 4: Making an Ensemble of All Recommenders

# %% [markdown]
# References
#
# #Dataset:https://www.kaggle.com/mgmarques/million-song-recommendation-engines
# #Links
# #1) https://towardsdatascience.com/create-music-recommendation-system-using-python-ce5401317159
# #2)https://github.com/llSourcell/recommender_live
# #3) https://github.com/llSourcell/recommender_live/blob/master/Song%20Recommender_Python.ipynb
# #4) https://towardsdatascience.com/how-to-build-a-simple-song-recommender-296fcbc8c85
